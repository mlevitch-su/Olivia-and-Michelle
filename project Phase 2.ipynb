# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')


products = pd.read_csv('Products.csv', encoding = "ISO-8859-1")
products.sample(10)
# Out:
#         NDB_Number                                          long_name  \
# 147523    45243014                               CREAMY PEANUT BUTTER
# 183470    45290732                                        GULF SHRIMP
# 67226     45148676  CLEAR AMERICAN, CLEAR AMERICAN ORGANIC, STRAWB...
# 31926     45078366    POLANER, ALL FRUIT SPREADABLE FRUIT, STRAWBERRY
# 176325    45282758                                   12 GUMMY CARROTS
# 38257     45088739                                          RAW HONEY
# 145584    45240500              WORLD MARKET, LEMON PRICKLY PEAR SODA
# 165884    45271126                                       CHIA PUDDING
# 204510    45338210                          GLUTEN FREE CORNBREAD MIX
# 116599    45206860  HORMEL, PIZZA READY, SAUCE & MEAT VEGGIES, SUP...
#
#        data_source     gtin_upc                         manufacturer  \
# 147523          LI  15400173742           Western Family Foods, Inc.
# ...

# %%
products[["long_name","ingredients_english"]].sample(10)
# Out:
#                                                 long_name  \
# 32239                               KALAMATA OLIVE SPREAD
# 91371                                     RED VELVET CAKE
# 23066       CLASSIC PASTA ZITI, ENRICHED MACARONI PRODUCT
# 40441                                 MARASCHINO CHERRIES
# 36174                              PEAR HALVES 100% JUICE
# 141078  IN BALANCE, INBAR, GLUTEN & ALLERGEN FREE SNAC...
# 75566            DUTCH VALLEY FOOD, SANDED TREE & SNOWMEN
# 182771                          SWEET CREAM SALTED BUTTER
# 144219                                ICED TEA WITH LEMON
# 95879                                           ICE CREAM
#
#                                       ingredients_english
# 32239   INGREDIENTS: KALAMATA OLIVES, RED WINE VINEGAR...
# 91371   CANE SUGAR, ENRICHED UNBLEACHED FLOUR (WHEAT F...
# 23066   DURUM SEMOLINA, NIACIN, FERROUS SULFATE (IRON)...
# 40441   CHERRIES, WATER, HIGH FRUCTOSE CORN SYRUP, COR...
# ...
